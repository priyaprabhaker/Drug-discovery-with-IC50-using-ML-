# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('./data/DDH Data with Properties.csv',sep=',')

# %%
df
# Out:
#           CID                                             SMILES  \
# 0     2744814  ClC1=CC(NC(=O)CSC2=NC=CC(=N2)C2=CSC(=N2)C2=CC=...
# 1     2821293  CN1N=C(C=C1C(F)(F)F)C1=CC=C(S1)C1=CC=NC(SCC(=O...
# 2     2820912  CSC1=C(C(C)=C(S1)C1=NC(C)=CS1)C1=CC=NC(SCC(=O)...
# 3     2820914  CSC1=C(C(C)=C(S1)C1=NC(C)=CS1)C1=CC=NC(SCC(=O)...
# 4     2744846  CC1=NC(=CS1)C1=NC(=CS1)C1=NC(SCC(=O)NC2=CC=C(C...
# ..        ...                                                ...
# 99   11796320      IC1=CC=C2N(CC3=CC4=CC=CC=C4S3)C(=O)C(=O)C2=C1
# 100  44398344     ClC1=C2C(=O)C(=O)N(CC3=CC4=CC=CC=C4S3)C2=CC=C1
# 101  44398231  IC1=CC=C2N(C\C=C\C3=CC4=CC=CC=C4S3)C(=O)C(=O)C...
# 102  44398546  ClC1=CC=C(NC(=O)C2=CC=C(CN3C(=O)C(=O)C4=CC(I)=...
# 103  44398436  IC1=CC=C2N(CC3=CC=C(S3)C(=O)N3CCCCC3)C(=O)C(=O...
#
#     MolecularFormula  MolecularWeight  \
# 0     C21H14Cl2N4OS2            473.4
# 1    C21H15ClF3N5OS2            510.0
# 2      C22H19ClN4OS4            519.1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 40 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CID                       104 non-null    int64
#  1   SMILES                    104 non-null    object
#  2   MolecularFormula          104 non-null    object
#  3   MolecularWeight           104 non-null    float64
#  4   InChI                     104 non-null    object
#  5   InChIKey                  101 non-null    object
#  6   IUPACName                 101 non-null    object
#  7   XLogP                     101 non-null    float64
#  8   ExactMass                 101 non-null    float64
#  9   MonoisotopicMass          101 non-null    float64
#  10  TPSA                      101 non-null    float64
#  11  Complexity                101 non-null    float64
#  12  Charge                    101 non-null    float64
# ...

# %%
df.describe()
# Out:
#                 CID  MolecularWeight       XLogP   ExactMass  \
# count  1.040000e+02       104.000000  101.000000  101.000000
# mean   3.539089e+07       367.867981    3.207921  378.261335
# std    4.443420e+07       100.488055    1.609763   78.756938
# min    0.000000e+00         0.000000   -0.600000  212.007805
# 25%    2.799801e+06       309.092500    2.200000  310.120509
# 50%    1.393569e+07       370.850000    3.400000  372.089226
# 75%    7.305647e+07       431.425000    4.300000  434.104876
# max    1.354276e+08       588.600000    7.300000  588.177766
#
#        MonoisotopicMass        TPSA  Complexity  Charge  HBondDonorCount  \
# count        101.000000  101.000000  101.000000   101.0       101.000000
# mean         378.221780  101.017822  576.336634     0.0         0.693069
# std           78.695752   34.974503  156.648286     0.0         0.796776
# min          212.007805   34.100000  242.000000     0.0         0.000000
# ...

# %%
df.describe().T
# Out:
#                           count          mean           std         min  \
# CID                       104.0  3.539089e+07  4.443420e+07    0.000000
# MolecularWeight           104.0  3.678680e+02  1.004881e+02    0.000000
# XLogP                     101.0  3.207921e+00  1.609763e+00   -0.600000
# ExactMass                 101.0  3.782613e+02  7.875694e+01  212.007805
# MonoisotopicMass          101.0  3.782218e+02  7.869575e+01  212.007805
# TPSA                      101.0  1.010178e+02  3.497450e+01   34.100000
# Complexity                101.0  5.763366e+02  1.566483e+02  242.000000
# Charge                    101.0  0.000000e+00  0.000000e+00    0.000000
# HBondDonorCount           101.0  6.930693e-01  7.967757e-01    0.000000
# HBondAcceptorCount        101.0  5.732673e+00  1.859522e+00    2.000000
# RotatableBondCount        101.0  4.079208e+00  2.591074e+00    0.000000
# HeavyAtomCount            101.0  2.521782e+01  5.027134e+00   13.000000
# ...

# %%
#This plost shows the missing values in the main file and in its column
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %%
df.iloc[80:95]# 86,88,91 rows dont have IDs either. So its no use of using it for prediction
# Out:
#          CID                                             SMILES  \
# 80   4614896       CN1C(=O)C(=O)C2=C1C=CC(=C2)S(=O)(=O)N1CCOCC1
# 81   4378077  O=C1N(CC2=CC=CC=C2)C2=C(C=C(C=C2)S(=O)(=O)N2CC...
# 82  73057090  CC1CCN(CC1)S(=O)(=O)C1=CC2=C(C=C1)N(CC1=CC=CC=...
# 83  73057089    CC1CCN(CC1)S(=O)(=O)C1=CC2=C(C=C1)N(C)C(=O)C2=O
# 84  73057388  CC1CC(C)CN(C1)S(=O)(=O)C1=CC2=C(C=C1)N(CC1=CC=...
# 85  73056765  CN1CCN(CC1)S(=O)(=O)C1=CC=C2N(CC3=CC=C4C=CC=CC...
# 86         0  O=C1N(CC2=CC=C3C=CC=CC3=C2)C2=CC=C(C=C2C1=O)S(...
# 87  73055922  O=C1N(CC2=CC=C3C=CC=CC3=C2)C2=CC=C(C=C2C1=O)S(...
# 88         0  O=C1N(CC2=CC=C3C=CC=CC3=C2)C2=CC=C(C=C2C1=O)S(...
# 89  73057088  O=C1N(CC2=CC=C3C=CC=CC3=C2)C2=CC=C(C=C2C1=O)S(...
# 90  73057091  CC1CCN(CC1)S(=O)(=O)C1=CC=C2N(CC3=CC=C4C=CC=CC...
# 91         0  CC1CC(C)CN(C1)S(=O)(=O)C1=CC=C2N(CC3=CC=C4C=CC...
# 92  44398160      CC1=C(CN2C(=O)C(=O)C3=CC(=CC=C23)C#N)C(C)=NO1
# 93  44398002     FC1=CC(Cl)=C(CN2C(=O)C(=O)C3=CC(I)=CC=C23)C=C1
# ...

# %%
df.iloc[40:50]# looking at the missing data seen on the heatmap between 40th to 50th index
# Out:
#         CID                                             SMILES  \
# 40  2774667  [O-][N+](=O)C1=C[N+]([O-])=C(C=C1)S(=O)(=O)C1=...
# 41  2799801  CCOC(=O)C(=C\NC1=CC=C(C=C1)S(=O)(=O)C1=CC=C(N\...
# 42  2775844  OC(=O)C1=CC=C(C=C1)S(=O)(=O)C1=CC(Br)=C(O)C(Br...
# 43  4270495        CC(=O)C1=CC=CC=C1S(=O)(=O)C1=CC=CC=C1C(O)=O
# 44    70871  [O-][N+](=O)C1=CC=C(C=C1)S(=O)(=O)C1=CC=C(C=C1...
# 45  2799800  CCOC(=O)C(=CNC1=CC=C(C=C1)S(=O)(=O)C1=CC=C(NC=...
# 46  2822496  FC(F)(F)C1=NN=C(N1)SC(=O)C1=CC=C(O1)C#CC1=CC=C...
# 47  3776668  CN1N=C(C=C1C1=CC=C(S1)C(=O)NC1=C(C(C)=NO1)[N+]...
# 48  2742278  CC1=C(C=C(O1)C(C)(C)C)C1=NNC(NS(=O)(=O)C2=CC=C...
# 49  2819269  CSC1=NNC(NC(=O)C2=CC=CS2)=C1S(=O)(=O)C1=CC=C(C...
#
#    MolecularFormula  MolecularWeight  \
# 40     C11H7ClN2O5S           314.70
# 41      C24H22N4O6S           494.50
# 42      C13H8Br2O5S           436.07
# 43        C15H12O5S           304.30
# 44       C12H8N2O6S           308.27
# 45     C28H32N2O10S           588.60
# ...

# %%
df[df['ExactMass']>=500]# the missing data has ID but few data are missing so check the similar molecular weight compounds
# Out:
#           CID                                             SMILES  \
# 1     2821293  CN1N=C(C=C1C(F)(F)F)C1=CC=C(S1)C1=CC=NC(SCC(=O...
# 2     2820912  CSC1=C(C(C)=C(S1)C1=NC(C)=CS1)C1=CC=NC(SCC(=O)...
# 3     2820914  CSC1=C(C(C)=C(S1)C1=NC(C)=CS1)C1=CC=NC(SCC(=O)...
# 6     2745640  FC(F)(F)C1=CC=C(NC(=O)CSC2=NC(=CC=N2)C2=CC(=NO...
# 16    2744870  CC(C)C1=CC=C(NC(=O)CSC2=NC=CC(=N2)C2=CSC(COC3=...
# 35    2774892  ClC(Cl)=C(Cl)C(=O)OC1=CC=C(C=C1)S(=O)(=O)C1=CC...
# 45    2799800  CCOC(=O)C(=CNC1=CC=C(C=C1)S(=O)(=O)C1=CC=C(NC=...
# 87   73055922  O=C1N(CC2=CC=C3C=CC=CC3=C2)C2=CC=C(C=C2C1=O)S(...
# 102  44398546  ClC1=CC=C(NC(=O)C2=CC=C(CN3C(=O)C(=O)C4=CC(I)=...
#
#      MolecularFormula  MolecularWeight  \
# 1     C21H15ClF3N5OS2            510.0
# 2       C22H19ClN4OS4            519.1
# 3       C22H19ClN4OS4            519.1
# 6    C22H13Cl2F3N4O2S            525.3
# 16     C25H23ClN4O2S2            511.1
# 35        C18H8Cl6O6S            565.0
# ...

# %%
# Looking at the test data
df_test=pd.read_csv('./data/DDH Data.csv',sep=',')
df_test
# Out:
#      Compound No.                                             SMILES  \
# 0               1  ClC1=CC(NC(=O)CSC2=NC=CC(=N2)C2=CSC(=N2)C2=CC=...
# 1               2  CN1N=C(C=C1C(F)(F)F)C1=CC=C(S1)C1=CC=NC(SCC(=O...
# 2               3  CSC1=C(C(C)=C(S1)C1=NC(C)=CS1)C1=CC=NC(SCC(=O)...
# 3               4  CSC1=C(C(C)=C(S1)C1=NC(C)=CS1)C1=CC=NC(SCC(=O)...
# 4               5  CC1=NC(=CS1)C1=NC(=CS1)C1=NC(SCC(=O)NC2=CC=C(C...
# ..            ...                                                ...
# 99            100      IC1=CC=C2N(CC3=CC4=CC=CC=C4S3)C(=O)C(=O)C2=C1
# 100           101     ClC1=C2C(=O)C(=O)N(CC3=CC4=CC=CC=C4S3)C2=CC=C1
# 101           102  IC1=CC=C2N(C\C=C\C3=CC4=CC=CC=C4S3)C(=O)C(=O)C...
# 102           103  ClC1=CC=C(NC(=O)C2=CC=C(CN3C(=O)C(=O)C4=CC(I)=...
# 103           104  IC1=CC=C2N(CC3=CC=C(S3)C(=O)N3CCCCC3)C(=O)C(=O...
#
#     pIC50 (IC50 in microM)  Unnamed: 3
# 0             -0.477121255         NaN
# 1                       -1         NaN
# ...

# %%
df.T #to ave better view of the columns in the data
# Out:
#                                                                         0    \
# CID                                                                 2744814
# SMILES                    ClC1=CC(NC(=O)CSC2=NC=CC(=N2)C2=CSC(=N2)C2=CC=...
# MolecularFormula                                             C21H14Cl2N4OS2
# MolecularWeight                                                       473.4
# InChI                     InChI=1S/C21H14Cl2N4OS2/c22-14-8-15(23)10-16(9...
# InChIKey                                        LILOEJREEQFTPM-UHFFFAOYSA-N
# IUPACName                 N-(3,5-dichlorophenyl)-2-[4-(2-phenyl-1,3-thia...
# XLogP                                                                   5.6
# ExactMass                                                        471.998609
# MonoisotopicMass                                                 471.998609
# TPSA                                                                  121.0
# ...

# %%
df.describe().T
# Out:
#                           count          mean           std         min  \
# CID                       104.0  3.539089e+07  4.443420e+07    0.000000
# MolecularWeight           104.0  3.678680e+02  1.004881e+02    0.000000
# XLogP                     101.0  3.207921e+00  1.609763e+00   -0.600000
# ExactMass                 101.0  3.782613e+02  7.875694e+01  212.007805
# MonoisotopicMass          101.0  3.782218e+02  7.869575e+01  212.007805
# TPSA                      101.0  1.010178e+02  3.497450e+01   34.100000
# Complexity                101.0  5.763366e+02  1.566483e+02  242.000000
# Charge                    101.0  0.000000e+00  0.000000e+00    0.000000
# HBondDonorCount           101.0  6.930693e-01  7.967757e-01    0.000000
# HBondAcceptorCount        101.0  5.732673e+00  1.859522e+00    2.000000
# RotatableBondCount        101.0  4.079208e+00  2.591074e+00    0.000000
# HeavyAtomCount            101.0  2.521782e+01  5.027134e+00   13.000000
# ...

# %%
#This plost shows the missing values in the main file and in its column
sns.heatmap(df_test.isna())
# Out:
# <Axes: >

# %%
#Unnamed:3 column holds no information so dropping that column
df_test.drop(columns="Unnamed: 3",inplace=True)

# %%
df_test
# Out:
#      Compound No.                                             SMILES  \
# 0               1  ClC1=CC(NC(=O)CSC2=NC=CC(=N2)C2=CSC(=N2)C2=CC=...
# 1               2  CN1N=C(C=C1C(F)(F)F)C1=CC=C(S1)C1=CC=NC(SCC(=O...
# 2               3  CSC1=C(C(C)=C(S1)C1=NC(C)=CS1)C1=CC=NC(SCC(=O)...
# 3               4  CSC1=C(C(C)=C(S1)C1=NC(C)=CS1)C1=CC=NC(SCC(=O)...
# 4               5  CC1=NC(=CS1)C1=NC(=CS1)C1=NC(SCC(=O)NC2=CC=C(C...
# ..            ...                                                ...
# 99            100      IC1=CC=C2N(CC3=CC4=CC=CC=C4S3)C(=O)C(=O)C2=C1
# 100           101     ClC1=C2C(=O)C(=O)N(CC3=CC4=CC=CC=C4S3)C2=CC=C1
# 101           102  IC1=CC=C2N(C\C=C\C3=CC4=CC=CC=C4S3)C(=O)C(=O)C...
# 102           103  ClC1=CC=C(NC(=O)C2=CC=C(CN3C(=O)C(=O)C4=CC(I)=...
# 103           104  IC1=CC=C2N(CC3=CC=C(S3)C(=O)N3CCCCC3)C(=O)C(=O...
#
#     pIC50 (IC50 in microM)
# 0             -0.477121255
# 1                       -1
# 2             -1.041392685
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Compound No.            104 non-null    int64
#  1   SMILES                  104 non-null    object
#  2   pIC50 (IC50 in microM)  104 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 2.6+ KB

# %%
df_test[df_test['pIC50 (IC50 in microM)']=='BLINDED']
# Out:
#     Compound No.                                             SMILES  \
# 3              4  CSC1=C(C(C)=C(S1)C1=NC(C)=CS1)C1=CC=NC(SCC(=O)...
# 22            23  COC1=CC=CC(=C1)C1=C(C#N)C(=O)NC(SCC(=O)NC2=CC=...
# 27            28      CC1=COC2=C1C(=O)C(=O)C1=C3CCCC(C)(C)C3=CC=C21
# 41            42  CCOC(=O)C(=C\NC1=CC=C(C=C1)S(=O)(=O)C1=CC=C(N\...
# 45            46  CCOC(=O)C(=CNC1=CC=C(C=C1)S(=O)(=O)C1=CC=C(NC=...
# 57            58  [O-][N+](=O)C1=C(C=CC(Cl)=C1)C1=CC=C(O1)C(=O)O...
# 62            63               ClC1=CC=C(C=C1)C(=O)OC1=CN=CC(Cl)=C1
# 67            68       CN1CCN(CC1)S(=O)(=O)C1=CC2=C(NC(=O)C2=O)C=C1
# 73            74          O=C1NC2=C(C=C(C=C2)S(=O)(=O)N2CCCCC2)C1=O
# 94            95    IC1=CC=C2N(CC3COC4=C(O3)C=CC=C4)C(=O)C(=O)C2=C1
#
#    pIC50 (IC50 in microM)
# 3                 BLINDED
# 22                BLINDED
# 27                BLINDED
# 41                BLINDED
# 45                BLINDED
# 57                BLINDED
# 62                BLINDED
# ...
